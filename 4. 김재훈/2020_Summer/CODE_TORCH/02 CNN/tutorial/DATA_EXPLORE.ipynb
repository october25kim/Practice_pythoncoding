# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = np.load('D:/CIFAR10/DATASET/train/train_0/image.npy')

# %%
a.shape
# Out:
# (32, 32, 3)

# %%
np.

# %%
plt.imshow(a[:,:,0])

# %%
plt.imshow(a[:,:,1])

# %%
plt.imshow(a[:,:,2])

# %%
np.mean(np.dstack([a['img'][:, :, 0] for i in range(len(a))]))
# Out:
# 0.55374545
